# %% [markdown]
# k.swathi
# 2211cs0101318
# Group-4

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# The dataset outlines the home guard strength across various districts for April 2024, detailing the number of units, allotted personnel, and actual  deployed strength. It provides a breakdown of male and female home guards, helping to analyze gender distribution in the workforce. Additionally, the dataset highlights vacancies. This data can be useful for assessing staffing efficiency, identifying shortages, and making informed decisions regarding deployment and recruitment.

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("home guards actual strength for the month April 2024.csv")

# %%
df
# Out:
#     SL. NO. NAME OF THE DISTRICT  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# 0         1      Bengaluru North                18               1850
# 1         2      Bengaluru Rural                15               1650
# 2         3      Bengaluru South                15               1850
# 3         4            Bagalkote                23               1000
# 4         5             Belagavi                30               1350
# 5         6              Ballari                22               1500
# 6         7                Bidar                15               1000
# 7         8        Chikkmagaluru                20                800
# 8         9       Chamarajanagar                 9                700
# 9        10         Chithradurga                14                700
# 10       11      Chikkaballapura                 7                700
# 11       12              Dharwad                 8                800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SL. NO.                    31 non-null     int64
#  1   NAME OF THE DISTRICT       31 non-null     object
#  2   NUMBER  OF UNITS           31 non-null     int64
#  3   ALLOTTED STRENGTH          31 non-null     int64
#  4   NO. OF HOME GUARDS(men)    31 non-null     int64
#  5   NO. OF HOME GUARDS(women)  31 non-null     int64
#  6   ACTUAL STRENGTH            31 non-null     int64
#  7   VACANCY                    31 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.1+ KB

# %%
df.shape
# Out:
# (31, 8)

# %%
df.describe()
# Out:
#          SL. NO.  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# count  31.000000         31.000000          31.000000
# mean   16.000000         14.064516         967.741935
# std     9.092121          5.999642         363.874701
# min     1.000000          7.000000         500.000000
# 25%     8.500000          9.000000         700.000000
# 50%    16.000000         14.000000         900.000000
# 75%    23.500000         15.000000        1100.000000
# max    31.000000         30.000000        1850.000000
#
#        NO. OF HOME GUARDS(men)  NO. OF HOME GUARDS(women)  ACTUAL STRENGTH  \
# count                31.000000                  31.000000        31.000000
# mean                712.161290                 137.806452       849.967742
# std                 259.839707                 182.916451       360.377162
# min                 193.000000                   0.000000       252.000000
# 25%                 544.500000                  61.000000       625.500000
# ...

# %%
df=df.fillna(0)
df
# Out:
#     SL. NO. NAME OF THE DISTRICT  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# 0         1      Bengaluru North                18               1850
# 1         2      Bengaluru Rural                15               1650
# 2         3      Bengaluru South                15               1850
# 3         4            Bagalkote                23               1000
# 4         5             Belagavi                30               1350
# 5         6              Ballari                22               1500
# 6         7                Bidar                15               1000
# 7         8        Chikkmagaluru                20                800
# 8         9       Chamarajanagar                 9                700
# 9        10         Chithradurga                14                700
# 10       11      Chikkaballapura                 7                700
# 11       12              Dharwad                 8                800
# ...

# %%
highest_vacancy_district = df.nlargest(1, 'VACANCY')[['NAME OF THE DISTRICT', 'VACANCY']]
print(highest_vacancy_district)
# Out:
#    NAME OF THE DISTRICT  VACANCY
# 19                Kolar      312

# %%
smallest_vacancy_district = df.nsmallest(1, 'VACANCY')[['NAME OF THE DISTRICT', 'VACANCY']]
print(smallest_vacancy_district)
# Out:
#    NAME OF THE DISTRICT  VACANCY
# 14                Gadag        0

# %%
bengaluru_strength = df[df['NAME OF THE DISTRICT'].str.contains("Bengaluru", case=False)][['NAME OF THE DISTRICT', 'ACTUAL STRENGTH']]
print(bengaluru_strength)
# Out:
#   NAME OF THE DISTRICT  ACTUAL STRENGTH
# 0      Bengaluru North             1616
# 1      Bengaluru Rural             1381
# 2      Bengaluru South             1804

# %%
Udupi_strength = df[df['NAME OF THE DISTRICT'].str.contains("Udupi", case=True)][['NAME OF THE DISTRICT', 'ACTUAL STRENGTH']]
print(Udupi_strength)
# Out:
#    NAME OF THE DISTRICT  ACTUAL STRENGTH
# 27                Udupi              429

# %%
Udupi_strength = df[df['NAME OF THE DISTRICT'].str.contains("Udupi", case=False)][['NAME OF THE DISTRICT', 'ACTUAL STRENGTH']]
print(Udupi_strength)
# Out:
#    NAME OF THE DISTRICT  ACTUAL STRENGTH
# 27                Udupi              429

# %%
highest_ALLOTTED_STRENGTH_district = df.nlargest(1, 'ALLOTTED STRENGTH')[['NAME OF THE DISTRICT', 'ALLOTTED STRENGTH']]
print(highest_ALLOTTED_STRENGTH_district)
# Out:
#   NAME OF THE DISTRICT  ALLOTTED STRENGTH
# 0      Bengaluru North               1850

# %%
highest_ALLOTTED_STRENGTH_district = df.nsmallest(1, 'ALLOTTED STRENGTH')[['NAME OF THE DISTRICT', 'ALLOTTED STRENGTH']]
print(highest_ALLOTTED_STRENGTH_district)
# Out:
#    NAME OF THE DISTRICT  ALLOTTED STRENGTH
# 18               Kodagu                500

# %%
bengaluru_strength_sorted = bengaluru_strength.sort_values(by="ACTUAL STRENGTH", ascending=False)
print(bengaluru_strength_sorted)
# Out:
#   NAME OF THE DISTRICT  ACTUAL STRENGTH
# 2      Bengaluru South             1804
# 0      Bengaluru North             1616
# 1      Bengaluru Rural             1381

# %%
total_strength = df[df['NAME OF THE DISTRICT'].str.contains("Bengaluru", case=False)]['ACTUAL STRENGTH'].sum()
print("Total Actual Strength of Bengaluru:", total_strength)
# Out:
# Total Actual Strength of Bengaluru: 4801

# %%
bengaluru_strength = df.query("`NAME OF THE DISTRICT`.str.contains('Bengaluru', case=False)", engine='python')[['NAME OF THE DISTRICT', 'ACTUAL STRENGTH']]
print(bengaluru_strength)
# Out:
#   NAME OF THE DISTRICT  ACTUAL STRENGTH
# 0      Bengaluru North             1616
# 1      Bengaluru Rural             1381
# 2      Bengaluru South             1804

# %%
bengaluru_strength = df.loc[df['NAME OF THE DISTRICT'].str.contains("Bengaluru", case=False), ['NAME OF THE DISTRICT', 'ACTUAL STRENGTH']]
print(bengaluru_strength)
# Out:
#   NAME OF THE DISTRICT  ACTUAL STRENGTH
# 0      Bengaluru North             1616
# 1      Bengaluru Rural             1381
# 2      Bengaluru South             1804

# %%
print(df.describe())
# Out:
#          SL. NO.  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# count  31.000000         31.000000          31.000000
# mean   16.000000         14.064516         967.741935
# std     9.092121          5.999642         363.874701
# min     1.000000          7.000000         500.000000
# 25%     8.500000          9.000000         700.000000
# 50%    16.000000         14.000000         900.000000
# 75%    23.500000         15.000000        1100.000000
# max    31.000000         30.000000        1850.000000
#
#        NO. OF HOME GUARDS(men)  NO. OF HOME GUARDS(women)  ACTUAL STRENGTH  \
# count                31.000000                  31.000000        31.000000
# mean                712.161290                 137.806452       849.967742
# std                 259.839707                 182.916451       360.377162
# min                 193.000000                   0.000000       252.000000
# 25%                 544.500000                  61.000000       625.500000
# ...

# %%
print(df.isnull().sum())
# Out:
# SL. NO.                      0
# NAME OF THE DISTRICT         0
# NUMBER  OF UNITS             0
# ALLOTTED STRENGTH            0
# NO. OF HOME GUARDS(men)      0
# NO. OF HOME GUARDS(women)    0
# ACTUAL STRENGTH              0
# VACANCY                      0
# dtype: int64

# %%
df['ALLOTMENT VS ACTUAL (%)'] = (df['ACTUAL STRENGTH'] / df['ALLOTTED STRENGTH']) * 100
print(df[['NAME OF THE DISTRICT', 'ALLOTMENT VS ACTUAL (%)']])
# Out:
#    NAME OF THE DISTRICT  ALLOTMENT VS ACTUAL (%)
# 0       Bengaluru North                87.351351
# 1       Bengaluru Rural                83.696970
# 2       Bengaluru South                97.513514
# 3             Bagalkote                98.500000
# 4              Belagavi                95.925926
# 5               Ballari                98.533333
# 6                 Bidar                97.700000
# 7         Chikkmagaluru                67.000000
# 8        Chamarajanagar                99.142857
# 9          Chithradurga                88.714286
# 10      Chikkaballapura                76.857143
# 11              Dharwad                78.750000
# 12           Davanagere                97.081413
# 13     Dakshina Kannada                86.500000
# 14                Gadag               100.000000
# 15            Kalaburgi                99.200000
# 16               Hassan                94.500000
# 17               Haveri                78.428571
# ...

# %%
top_vacancies = df.nlargest(5, 'VACANCY')[['NAME OF THE DISTRICT', 'VACANCY']]
bottom_vacancies = df.nsmallest(5, 'VACANCY')[['NAME OF THE DISTRICT', 'VACANCY']]
print("Top 5 Districts with Highest Vacancies:\n", top_vacancies)
print("\nBottom 5 Districts with Lowest Vacancies:\n", bottom_vacancies)
# Out:
# Top 5 Districts with Highest Vacancies:
#     NAME OF THE DISTRICT  VACANCY
# 19                Kolar      312
# 1       Bengaluru Rural      269
# 7         Chikkmagaluru      264
# 18               Kodagu      248
# 28       Uttara Kannada      244
#
# Bottom 5 Districts with Lowest Vacancies:
#     NAME OF THE DISTRICT  VACANCY
# 14                Gadag        0
# 20               Koppal        5
# 8        Chamarajanagar        6
# 15            Kalaburgi        8
# 3             Bagalkote       15

# %%
df['MEN VS WOMEN (%)'] = (df['NO. OF HOME GUARDS(women)'] / df['NO. OF HOME GUARDS(men)']) * 100
print(df[['NAME OF THE DISTRICT', 'MEN VS WOMEN (%)']])
# Out:
#    NAME OF THE DISTRICT  MEN VS WOMEN (%)
# 0       Bengaluru North         93.764988
# 1       Bengaluru Rural         45.521602
# 2       Bengaluru South         68.440710
# 3             Bagalkote         10.923423
# 4              Belagavi          4.943274
# 5               Ballari          7.256894
# 6                 Bidar         14.671362
# 7         Chikkmagaluru         13.080169
# 8        Chamarajanagar         10.158730
# 9          Chithradurga          9.717314
# 10      Chikkaballapura         20.627803
# 11              Dharwad         27.789047
# 12           Davanagere         11.072056
# 13     Dakshina Kannada         38.400000
# 14                Gadag          0.000000
# 15            Kalaburgi          9.613260
# 16               Hassan          6.578947
# 17               Haveri         10.240964
# 18               Kodagu         30.569948
# 19                Kolar         17.615894
# 20               Koppal          9.621451
# ...

# %%
total_vacancy = df['VACANCY'].sum()
print("Total Vacancy Across All Districts:", total_vacancy)
# Out:
# Total Vacancy Across All Districts: 3651

# %%
highest_men = df.nlargest(1, 'NO. OF HOME GUARDS(men)')[['NAME OF THE DISTRICT', 'NO. OF HOME GUARDS(men)']]
highest_women = df.nlargest(1, 'NO. OF HOME GUARDS(women)')[['NAME OF THE DISTRICT', 'NO. OF HOME GUARDS(women)']]
print("District with Highest Male Guards:\n", highest_men)
print("\nDistrict with Highest Female Guards:\n", highest_women)
# Out:
# District with Highest Male Guards:
#    NAME OF THE DISTRICT  NO. OF HOME GUARDS(men)
# 5              Ballari                     1378
#
# District with Highest Female Guards:
#    NAME OF THE DISTRICT  NO. OF HOME GUARDS(women)
# 0      Bengaluru North                        782

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['NAME OF THE DISTRICT'], df['ACTUAL STRENGTH'], label="Actual Strength", alpha=0.7)
plt.bar(df['NAME OF THE DISTRICT'], df['ALLOTTED STRENGTH'], label="Allotted Strength", alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel("District")
plt.ylabel("Strength")
plt.title("Actual vs. Allotted Home Guard Strength")
plt.legend()
plt.show()

# %%
zero_vacancy = df[df['VACANCY'] == 0][['NAME OF THE DISTRICT', 'VACANCY']]
print("Districts with No Vacancies:\n", zero_vacancy)
# Out:
# Districts with No Vacancies:
#     NAME OF THE DISTRICT  VACANCY
# 14                Gadag        0

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=df['NAME OF THE DISTRICT'], y=df['ACTUAL STRENGTH'], color='blue', label='Actual Strength')
sns.barplot(x=df['NAME OF THE DISTRICT'], y=df['ALLOTTED STRENGTH'], color='red', alpha=0.5, label='Allotted Strength')
plt.xticks(rotation=90)
plt.xlabel("District")
plt.ylabel("Strength")
plt.title("Actual vs. Allotted Strength per District")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7, 7))
men_total = df['NO. OF HOME GUARDS(men)'].sum()
women_total = df['NO. OF HOME GUARDS(women)'].sum()
plt.pie([men_total, women_total], labels=['Men', 'Women'], autopct='%1.1f%%', colors=['blue', 'pink'], startangle=90)
plt.title("Home Guards Gender Distribution")
plt.show()

# %%
top_vacancies = df.nlargest(10, 'VACANCY')

plt.figure(figsize=(10, 6))
sns.barplot(x=top_vacancies['NAME OF THE DISTRICT'], y=top_vacancies['VACANCY'], palette="Reds_r")
plt.xticks(rotation=90)
plt.xlabel("District")
plt.ylabel("Vacancy Count")
plt.title("Top 10 Districts with Highest Vacancies")
plt.show()
# Out:
# C:\Users\kswat\AppData\Local\Temp\ipykernel_10692\3561035664.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vacancies['NAME OF THE DISTRICT'], y=top_vacancies['VACANCY'], palette="Reds_r")

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['ALLOTTED STRENGTH'], y=df['ACTUAL STRENGTH'])
plt.xlabel("Allotted Strength")
plt.ylabel("Actual Strength")
plt.title("Actual Strength vs. Allotted Strength")
plt.show()

# %%
plt.figure(figsize=(7, 7))
men_total = df['NO. OF HOME GUARDS(men)'].sum()
women_total = df['NO. OF HOME GUARDS(women)'].sum()
plt.pie([men_total, women_total], labels=['Men', 'Women'], autopct='%1.1f%%', colors=['blue', 'pink'], startangle=90)
plt.title("Home Guards Gender Distribution")
plt.show()

# %%
df
# Out:
#     SL. NO. NAME OF THE DISTRICT  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# 0         1      Bengaluru North                18               1850
# 1         2      Bengaluru Rural                15               1650
# 2         3      Bengaluru South                15               1850
# 3         4            Bagalkote                23               1000
# 4         5             Belagavi                30               1350
# 5         6              Ballari                22               1500
# 6         7                Bidar                15               1000
# 7         8        Chikkmagaluru                20                800
# 8         9       Chamarajanagar                 9                700
# 9        10         Chithradurga                14                700
# 10       11      Chikkaballapura                 7                700
# 11       12              Dharwad                 8                800
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['VACANCY'], bins=10, kde=True, color="red")
plt.xlabel("Vacancy Count")
plt.ylabel("Number of Districts")
plt.title("Vacancy Distribution Across Districts")
plt.show()

# %%
top_vacancies = df.nlargest(10, 'VACANCY')

plt.figure(figsize=(10, 6))
sns.barplot(x=top_vacancies['NAME OF THE DISTRICT'], y=top_vacancies['VACANCY'], palette="Reds_r")
plt.xticks(rotation=90)
plt.xlabel("District")
plt.ylabel("Vacancy Count")
plt.title("Top 10 Districts with Highest Vacancies")
plt.show()
# Out:
# C:\Users\kswat\AppData\Local\Temp\ipykernel_10692\3561035664.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vacancies['NAME OF THE DISTRICT'], y=top_vacancies['VACANCY'], palette="Reds_r")

# %%
men_total = df['NO. OF HOME GUARDS(men)'].sum()
women_total = df['NO. OF HOME GUARDS(women)'].sum()

# %%
men_total
# Out:
# 22077

# %%
women_total
# Out:
# 4272

# %%
plt.figure(figsize=(7, 7)) 
plt.pie([men_total, women_total], labels=['Men', 'Women'], autopct='%1.1f%%', colors=['red', 'yellow'], startangle=90)
plt.title("Home Guards Gender Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['ALLOTTED STRENGTH'], y=df['ACTUAL STRENGTH'], color='blue', alpha=0.7)
plt.xlabel("Allotted Strength")
plt.ylabel("Actual Strength")
plt.title("Actual Strength vs. Allotted Strength")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.regplot(x=df['ALLOTTED STRENGTH'], y=df['ACTUAL STRENGTH'], scatter_kws={'color':'blue'}, line_kws={'color':'red'})
plt.xlabel("Allotted Strength")
plt.ylabel("Actual Strength")
plt.title("Actual Strength vs. Allotted Strength with Trend Line")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['ACTUAL STRENGTH'], color='blue')
plt.ylabel("Actual Strength")
plt.title("Distribution of Actual Strength Across Districts")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df[['ALLOTTED STRENGTH', 'ACTUAL STRENGTH']], palette="Set2")
plt.ylabel("Strength")
plt.title("Comparison of Allotted and Actual Strength")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['VACANCY'], color='red')
plt.ylabel("Vacancies")
plt.title("Distribution of Vacancies Across Districts")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['NAME OF THE DISTRICT'], y=df['ACTUAL STRENGTH'], palette="Blues")
plt.xticks(rotation=90)
plt.xlabel("District")
plt.ylabel("Actual Strength")
plt.title("Actual Strength Distribution by District")
plt.show()
# Out:
# C:\Users\kswat\AppData\Local\Temp\ipykernel_10692\3686792955.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['NAME OF THE DISTRICT'], y=df['ACTUAL STRENGTH'], palette="Blues")

# %% [markdown]
# ## data analysis description:

# %% [markdown]
# The government dataset concerning home guard strength in different districts for April 2024. It probably has data preprocessing tasks like loading  and cleaning the dataset to make it accurate. The analysis is centered around major metrics such as home guard units, allotted strength versus actual strength, and vacancies. In addition, gender distribution is discussed by contrasting male and female numbers of home guards in various  zones. Trends might be made noticeable through the usage of bar plots and histograms and  better understand the data. The analysis contributes to    identifying shortcomings in staffing levels, assessing worker deployment, as well as aiding in the enhancement of recruitment planning.
